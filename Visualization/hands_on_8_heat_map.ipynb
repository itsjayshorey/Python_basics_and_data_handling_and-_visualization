# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")

# %%
sns.countplot(x='class',data=titanic,palette=['red','green','blue'])
# Out:
# C:\Users\itsja\AppData\Local\Temp\ipykernel_39528\4197059665.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='class',data=titanic,palette=['red','green','blue'])
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(x='class',data=titanic,palette='Blues')
# Out:
# C:\Users\itsja\AppData\Local\Temp\ipykernel_39528\3804450161.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='class',data=titanic,palette='Blues')
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(x='class',data=titanic,palette='Pinks')
# Out:
# C:\Users\itsja\AppData\Local\Temp\ipykernel_39528\1634640780.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='class',data=titanic,palette='Pinks')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\itsja\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File c:\Users\itsja\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
# ...
