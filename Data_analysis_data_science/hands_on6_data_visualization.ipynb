# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv('time_series.csv')
data.head
# Out:
# <bound method NDFrame.head of          Date        AAPL        ADBE         CVX        GOOG         IBM  \
# 0    3-Jan-07   11.107141   38.869999   50.777351  251.001007   79.242500
# 1    1-Feb-07   10.962033   39.250000   48.082939  224.949951   74.503204
# 2    1-Mar-07   12.037377   41.700001   51.900383  229.309311   75.561348
# 3    2-Apr-07   12.930043   41.560001   54.588032  235.925919   81.934280
# 4    1-May-07   15.701322   44.060001   57.598267  249.204208   85.786057
# ..        ...         ...         ...         ...         ...         ...
# 116  1-Sep-16  111.987015  108.540001  100.933739  804.059998  156.186905
# 117  3-Oct-16  112.472404  107.510002  102.728424  809.900024  151.113403
# 118  1-Nov-16  110.042900  102.809998  110.502274  775.880005  160.947403
# 119  1-Dec-16  115.320023  102.949997  116.584061  792.450012  164.687836
# 120  3-Jan-17  121.104935  113.820000  110.759811  823.830017  174.420883
#
# ...

# %%
plt.plot(data['Date'],data['GOOG'])

# %%
data = pd.read_csv('national_parks.csv')

# %%
data.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
plt.hist(data['GrandCanyon'])
# Out:
# (array([ 5.,  9., 10.,  2.,  1.,  9., 16.,  2.,  1.,  2.]),
#  array([1253000. , 1753123.8, 2253247.6, 2753371.4, 3253495.2, 3753619. ,
#         4253742.8, 4753866.6, 5253990.4, 5754114.2, 6254238. ]),
#  <BarContainer object of 10 artists>)

# %%
data = pd.read_csv('types_movies.csv')

# %%
data.head()
# Out:
#     Sector  Percentage
# 0   Sci-Fi          20
# 1    Drama          35
# 2   Action          25
# 3   Comedy           5
# 4  Romance          15

# %%
plt.pie(data['Percentage'],labels=data['Sector'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21e2e099590>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'Sci-Fi'),
#   Text(-0.7778174593052023, 0.7778174593052024, 'Drama'),
#   Text(-0.49938956806635254, -0.9801071672559598, 'Action'),
#   Text(0.4993895336547568, -0.9801071847895437, 'Comedy'),
#   Text(0.9801071789450159, -0.49938954512528877, 'Romance')],
#  [Text(0.4854101933230228, 0.35267115592022213, '20.0%'),
#   Text(-0.42426406871192845, 0.4242640687119285, '35.0%'),
#   Text(-0.2723943098543741, -0.5346039094123416, '25.0%'),
#   Text(0.27239429108441277, -0.5346039189761147, '5.0%'),
#   Text(0.5346039157881904, -0.27239429734106657, '15.0%')])

# %%
data = pd.read_csv('time_series.csv')
matrix = data.select_dtypes(include='number').corr()

# %%
sns.heatmap(matrix,annot=True,annot_kws={'alpha': .9, 'fontsize': 10})
# Out:
# <Axes: >
