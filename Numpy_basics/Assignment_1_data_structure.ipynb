# %% [markdown]
# ![image.png](attachment:image.png)

# %%
myList = [10,20,30,'apple',True,8.10]
myList.append(30)
myList.append(40)
reversedList=[myList[-i] for i in range(1,len(myList)) ]

# %%
myList.reverse()
print(myList)
# Out:
# [40, 30, 8.1, True, 'apple', 30, 20, 10]

# %%
print(reversedList)
# Out:
# [40, 30, 8.1, True, 'apple', 30, 20]

# %%
myList[::-1]
# Out:
# [10, 20, 30, 'apple', True, 8.1, 30, 40]

# %%
dicti = {'data':1,'information':2,'text':3}

# %%
dicti.pop('text')
# Out:
# 3

# %%
dicti
# Out:
# {'data': 1, 'information': 2}

# %%
dicti['features']=3

# %%
dicti['data']
# Out:
# 1

# %%
dicti
# Out:
# {'data': 1, 'information': 2, 'features': 3}

# %%
my_tuple=(1,2,3,'apple','mango')

# %%
numeric_tuple=(10,20,30,40,50)

# %%
min(numeric_tuple)
# Out:
# 10

# %%
r1=my_tuple+numeric_tuple

# %%
r1
# Out:
# (1, 2, 3, 'apple', 'mango', 10, 20, 30, 40, 50)

# %%
newdupli=my_tuple*2

# %%
newdupli
# Out:
# (1, 2, 3, 'apple', 'mango', 1, 2, 3, 'apple', 'mango')

# %%
set1={1,2,3,4,5}
set2={2,3,7,6,1}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
set1|set2
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
set1.intersection(set2)
# Out:
# {1, 2, 3}

# %%
set1.difference(set2)
# Out:
# {4, 5}
