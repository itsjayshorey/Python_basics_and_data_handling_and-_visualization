# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
arr=np.arange(2,11)

# %%
arr.reshape(3,3)
# Out:
# array([[ 2,  3,  4],
#        [ 5,  6,  7],
#        [ 8,  9, 10]])

# %%
l = int(input('Enter the value of elements you want in the array'))
input_values =np.zeros(l)

# %%
for i in range(l):
    input_values[i]=int(input(f'Enter the &{i}th value'))

# %%
input_values.dtype=int
input_values.dtype
# Out:
# dtype('int32')

# %%
input_values
# Out:
# array([         0, 1072693248,          0, 1073741824,          0,
#        1074266112,          0, 1074790400])

# %%
input_values.dtype=float

# %%
input_values
# Out:
# array([1., 2., 3., 4.])

# %% [markdown]
# question-3

# %%
ar = np.array([10,20,30])

# %%
ar2=np.array([40,50,60,70,80,90])

# %%
ar1=np.hstack((ar,ar2))
ar
# Out:
# array([10, 20, 30])

# %%
ar3=np.array([40,50,60])

# %%
sumarr=ar+ar3

# %%
sumarr
# Out:
# array([50, 70, 90])

# %%
array1=np.linspace(10,90,9)

# %%
array1=array1.reshape(3,3)

# %%
array1[:1]
# Out:
# array([[10., 20., 30.]])

# %%
array1[0]
# Out:
# array([10., 20., 30.])

# %%
array1[2:,-1]
# Out:
# array([90.])
