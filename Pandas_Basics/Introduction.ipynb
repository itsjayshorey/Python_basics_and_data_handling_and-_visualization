# %% [markdown]
# # Panel Data

# %%
import pandas as pd

# %%
df =pd.read_csv('new_insurance_data.csv')
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
empty = pd.Series()
empty
# Out:
# Series([], dtype: object)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
series = pd.Series(['1','2','3','4'],index=['a','b','c','d'])
series
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dataf = pd.DataFrame()
print(dataf)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
type(dataf)
# Out:
# pandas.core.frame.DataFrame

# %%
dataf = pd.DataFrame(series)
dataf
# Out:
#    0
# a  1
# b  2
# c  3
# d  4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# merge(), join(), concat()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.info
# Out:
# <bound method DataFrame.info of        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
# df.info(null_counts=True)depreceated
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
df.isnull()
# Out:
#         age    sex    bmi  children  smoker  Claim_Amount  past_consultations  \
# 0     False  False  False     False   False         False               False
# 1     False  False  False     False   False         False               False
# 2     False  False  False     False   False         False               False
# 3     False  False  False     False   False         False               False
# 4     False  False  False     False   False         False               False
# ...     ...    ...    ...       ...     ...           ...                 ...
# 1333  False  False  False     False   False         False               False
# 1334  False  False  False     False   False         False               False
# 1335  False  False  False     False   False         False               False
# 1336  False  False  False     False   False         False               False
# 1337  False  False  False     False   False         False               False
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.shape
# Out:
# (1338, 13)

# %%
df.dtypes
# Out:
# age                                float64
# sex                                 object
# bmi                                float64
# children                           float64
# smoker                              object
# Claim_Amount                       float64
# past_consultations                 float64
# num_of_steps                       float64
# Hospital_expenditure               float64
# NUmber_of_past_hospitalizations    float64
# Anual_Salary                       float64
# region                              object
# charges                            float64
# dtype: object

# %%
float_obj=[_ for _ in df.dtypes=='float']

# %%
df.select_dtypes(include=['float']).mean()
# Out:
# age                                3.931001e+01
# bmi                                3.066511e+01
# children                           1.090773e+00
# Claim_Amount                       3.336133e+04
# past_consultations                 1.521622e+01
# num_of_steps                       9.100047e+05
# Hospital_expenditure               1.584179e+07
# NUmber_of_past_hospitalizations    1.060629e+00
# Anual_Salary                       3.696849e+08
# charges                            1.327042e+04
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.Anual_Salary = df.Anual_Salary.astype(float)

# %%
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
df=df.fillna(df.mean)

# %%
df['Anual_Salary'] = pd.to_numeric(df['Anual_Salary'], errors='coerce')

# %%
df['Anual_Salary'] = df['Anual_Salary'].fillna(0).astype('int')

# %%
df.Anual_Salary = df.Anual_Salary.astype(int)

# %%
df.dtypes
# Out:
# age                                 object
# sex                                 object
# bmi                                 object
# children                            object
# smoker                              object
# Claim_Amount                        object
# past_consultations                  object
# num_of_steps                        object
# Hospital_expenditure                object
# NUmber_of_past_hospitalizations     object
# Anual_Salary                         int32
# region                              object
# charges                            float64
# dtype: object

# %%
df.drop(['smoker','bmi'],axis=1)
# Out:
#        age     sex children Claim_Amount past_consultations num_of_steps  \
# 0     18.0    male      0.0  29087.54313               17.0     715428.0
# 1     18.0    male      0.0  39053.67437                7.0     699157.0
# 2     18.0    male      0.0  39023.62759               19.0     702341.0
# 3     18.0    male      0.0  28185.39332               11.0     700250.0
# 4     18.0    male      0.0  14697.85941               16.0     711584.0
# ...    ...     ...      ...          ...                ...          ...
# 1333  33.0  female      0.0  63142.25346               32.0    1091267.0
# 1334  31.0  female      1.0  43419.95227               31.0    1107872.0
# 1335  52.0    male      3.0  52458.92353               25.0    1092005.0
# 1336  45.0    male      0.0  69927.51664               34.0    1106821.0
# 1337  54.0  female      0.0  63982.80926               31.0    1100328.0
#
#      Hospital_expenditure NUmber_of_past_hospitalizations  Anual_Salary  \
# ...

# %%
df.iloc[500:,:2]
# Out:
#        age     sex
# 500   37.0    male
# 501   40.0    male
# 502   42.0  female
# 503   42.0  female
# 504   42.0  female
# ...    ...     ...
# 1333  33.0  female
# 1334  31.0  female
# 1335  52.0    male
# 1336  45.0    male
# 1337  54.0  female
#
# [838 rows x 2 columns]

# %%
df.iloc[:,4]
# Out:
# 0        no
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333    yes
# 1334    yes
# 1335    yes
# 1336    yes
# 1337    yes
# Name: smoker, Length: 1338, dtype: object

# %%
df.loc[10:20,'smoker']
# Out:
# 10    no
# 11    no
# 12    no
# 13    no
# 14    no
# 15    no
# 16    no
# 17    no
# 18    no
# 19    no
# 20    no
# Name: smoker, dtype: object

# %%
df.loc[10:20,'smoker':'region']
# Out:
#    smoker Claim_Amount                                 past_consultations  \
# 10     no  16980.21403                                                2.0
# 11     no  1920.136268  <bound method DataFrame.mean of        age    ...
# 12     no  3927.892067                                                4.0
# 13     no  46780.54648                                                8.0
# 14     no  36778.50383                                                3.0
# 15     no   12515.9537                                               15.0
# 16     no  14682.87151                                                3.0
# 17     no  24340.53616                                                2.0
# 18     no  45329.43416                                                2.0
# 19     no  12590.76762                                               14.0
# 20     no    26792.207                                               10.0
#
#    num_of_steps                               Hospital_expenditure  \
# ...

# %%
df['val']=1

# %%
df
# Out:
#        age     sex     bmi children smoker Claim_Amount past_consultations  \
# 0     18.0    male   23.21      0.0     no  29087.54313               17.0
# 1     18.0    male   30.14      0.0     no  39053.67437                7.0
# 2     18.0    male   33.33      0.0     no  39023.62759               19.0
# 3     18.0    male   33.66      0.0     no  28185.39332               11.0
# 4     18.0    male    34.1      0.0     no  14697.85941               16.0
# ...    ...     ...     ...      ...    ...          ...                ...
# 1333  33.0  female   35.53      0.0    yes  63142.25346               32.0
# 1334  31.0  female  38.095      1.0    yes  43419.95227               31.0
# 1335  52.0    male  34.485      3.0    yes  52458.92353               25.0
# 1336  45.0    male   30.36      0.0    yes  69927.51664               34.0
# 1337  54.0  female   47.41      0.0    yes  63982.80926               31.0
#
# ...

# %%
df['age']
# Out:
# 0       18.0
# 1       18.0
# 2       18.0
# 3       18.0
# 4       18.0
#         ...
# 1333    33.0
# 1334    31.0
# 1335    52.0
# 1336    45.0
# 1337    54.0
# Name: age, Length: 1338, dtype: object

# %%
df['age']=pd.to_numeric(df['age'],errors='coerce')

# %%
f = lambda x: x * x  # This lambda function squares the input x.
df['age'] = df['age'].apply(f)  # Apply the lambda function to each value in the 'age' column.

# %%
df.age
# Out:
# 0        324.0
# 1        324.0
# 2        324.0
# 3        324.0
# 4        324.0
#          ...
# 1333    1089.0
# 1334     961.0
# 1335    2704.0
# 1336    2025.0
# 1337    2916.0
# Name: age, Length: 1338, dtype: float64

# %%
df.sort_values(by='age',ascending=False)
# Out:
#         age     sex     bmi children smoker Claim_Amount past_consultations  \
# 993  4096.0  female   39.05      3.0     no  20212.55884               16.0
# 960  4096.0  female    39.7      0.0     no   27146.6621               25.0
# 979  4096.0    male    25.6      2.0     no   57544.4014                7.0
# 978  4096.0  female   39.33      0.0     no  14630.20499                8.0
# 976  4096.0  female  32.965      0.0     no  58313.91875               23.0
# ..      ...     ...     ...      ...    ...          ...                ...
# 111     NaN  female   28.82      0.0     no  43225.25701               18.0
# 129     NaN  female   31.92      0.0     no  16230.60072                7.0
# 210     NaN  female   42.13      1.0     no  37708.33994               17.0
# 286     NaN    male  28.595      1.0     no  24042.82862                5.0
# 365     NaN    male   17.86      1.0     no  50569.01375               15.0
#
# ...

# %%
df.sort_values(by='age',ascending=True)
# Out:
#        age     sex     bmi children smoker Claim_Amount past_consultations  \
# 0    324.0    male   23.21      0.0     no  29087.54313               17.0
# 123  324.0  female   40.28      0.0     no  10335.21512               13.0
# 124  324.0  female   37.29      1.0     no  18567.40325               18.0
# 59   324.0    male    35.2      1.0     no  43570.16888               18.0
# 58   324.0    male   33.77      1.0     no  7470.067505               12.0
# ..     ...     ...     ...      ...    ...          ...                ...
# 111    NaN  female   28.82      0.0     no  43225.25701               18.0
# 129    NaN  female   31.92      0.0     no  16230.60072                7.0
# 210    NaN  female   42.13      1.0     no  37708.33994               17.0
# 286    NaN    male  28.595      1.0     no  24042.82862                5.0
# 365    NaN    male   17.86      1.0     no  50569.01375               15.0
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
filter1 = (df["age"]>450) & (df["age"]<2000)

# %%
filter_review = df[filter1]

# %%
filter_review
# Out:
#          age     sex     bmi children smoker Claim_Amount past_consultations  \
# 44     484.0    male   26.84      0.0     no   34164.6985                8.0
# 45     484.0    male   33.77      0.0     no   25171.9796               13.0
# 70     529.0    male   32.56      0.0     no  24081.47641               13.0
# 71     529.0    male    34.4      0.0     no   18674.7197               19.0
# 74     529.0    male   41.91      0.0     no  34420.61859                6.0
# ...      ...     ...     ...      ...    ...          ...                ...
# 1307  1936.0  female   43.89      2.0    yes  39751.23146               23.0
# 1328  1936.0  female   38.06      0.0    yes  76028.85348               25.0
# 1331   784.0    male    36.4      1.0    yes  55590.75527               26.0
# 1333  1089.0  female   35.53      0.0    yes  63142.25346               32.0
# 1334   961.0  female  38.095      1.0    yes  43419.95227               31.0
#
# ...

# %%
filter1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333     True
# 1334     True
# 1335    False
# 1336    False
# 1337    False
# Name: age, Length: 1338, dtype: bool

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
